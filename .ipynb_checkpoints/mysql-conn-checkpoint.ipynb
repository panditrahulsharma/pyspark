# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="0.0.0.0",
  user="root",
  password="Meta@123"
)

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7f206b98c940>

# %%
#create database
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE rahul")

# %%
#show databases
mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('rahul',)
# ('sys',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="0.0.0.0",
  user="root",
  password="Meta@123",
  database="rahul"
)

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
#insert data
mycursor = mydb.cursor()
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.
